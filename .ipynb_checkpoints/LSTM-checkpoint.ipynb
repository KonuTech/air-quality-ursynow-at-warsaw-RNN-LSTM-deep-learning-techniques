# %% [markdown]
# Kaggle LSTM:
# https://www.kaggle.com/amirrezaeian/time-series-data-analysis-using-lstm-tutorial

# %% [markdown]
# https://aqicn.org/data-platform/register/

# %% [markdown]
# Note: the daily AQI is based on the 24 hours average of hourly readings.

# %% [markdown]
# Ursynów, Warszawa, Mazowieckie past 85 months daily average AQI
# Data Sources
# Regional Inspectorate for Environmental Protection in Warsaw (Wojewódzki Inspektorat Ochrony Środowiska w Warszawie) - Główny inspektorat ochrony środowiska

# %%
import os

# %%
os.chdir("C:/Users/KonuTech/Downloads/deep-learning-LSTM-air-quality-Ursynow-at-Warsaw")

# %%
from functions import *

# %%
df = pd.read_csv("ursynów,-warszawa, mazowieckie-air-quality.csv", infer_datetime_format="True", parse_dates=["date"], index_col="date", delimiter=',')

# %%
df.columns = df.columns.str.strip()

# %%
cols = list(df.columns)
for i in range(len(cols)):
    df[cols[i]] = pd.to_numeric(df[cols[i]], errors='coerce')

# %%
df.sort_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2475 entries, 2013-12-31 to 2021-01-01
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pm25    2432 non-null   float64
#  1   pm10    2433 non-null   float64
#  2   o3      2441 non-null   float64
#  3   no2     2417 non-null   float64
#  4   so2     1628 non-null   float64
#  5   co      588 non-null    float64
# dtypes: float64(6)
# memory usage: 135.4 KB

# %%
df.describe()
# Out:
#           pm25     pm10       o3      no2      so2      co
# count 2432.000 2433.000 2441.000 2417.000 1628.000 588.000
# mean    62.799   25.111   24.838    9.423    2.994   4.446
# std     28.816   12.229   11.927    5.505    2.109   2.733
# min     11.000    3.000    1.000    1.000    1.000   1.000
# 25%     42.000   16.000   16.000    6.000    2.000   3.000
# 50%     56.500   23.000   24.000    8.000    2.000   4.000
# 75%     78.000   31.000   33.000   12.000    4.000   6.000
# max    174.000   86.000   74.000   43.000   25.000  20.000

# %% [markdown]
# ### Dealing with NULL values of series

# %%
df.isna().sum()
# Out:
# pm25      43
# pm10      42
# o3        34
# no2       58
# so2      847
# co      1887
# dtype: int64

# %%
df[df["pm25"].isna() == True]
# Out:
#             pm25   pm10     o3    no2   so2    co
# date
# 2013-12-31   nan 41.000 14.000  6.000 4.000 4.000
# 2014-05-31   nan  8.000 28.000  3.000 3.000   nan
# 2014-07-13   nan 13.000 43.000  5.000 2.000 4.000
# 2014-10-06   nan 28.000 28.000  6.000 3.000 4.000
# 2014-10-12   nan 25.000 22.000  9.000 1.000   nan
# 2014-11-01   nan 46.000 12.000  9.000 6.000   nan
# 2014-12-31   nan 27.000 16.000  4.000 2.000 8.000
# 2015-01-30   nan 22.000 13.000 10.000 5.000 6.000
# 2015-04-25   nan 17.000 27.000  9.000 2.000   nan
# 2015-10-14   nan 35.000 30.000  6.000 6.000 4.000
# 2016-01-03   nan 38.000  9.000  8.000 6.000   nan
# 2016-01-23   nan    nan  9.000 16.000 8.000   nan
# 2016-01-24   nan 46.000 11.000 16.000 5.000   nan
# 2016-01-25   nan 36.000  2.000 16.000 4.000   nan
# 2016-01-26   nan 31.000 11.000 15.000 5.000 4.000
# 2017-04-03   nan 28.000 35.000  9.000 1.000   nan
# 2017-09-09   nan 24.000  7.000 14.000 2.000   nan
# 2017-09-24   nan 28.000 17.000  7.000   nan   nan
# 2017-10-13   nan    nan 15.000  9.000 2.000   nan
# 2017-10-14   nan    nan 13.000  9.000 1.000   nan
# 2017-10-15   nan 45.000 18.000 18.000 2.000   nan
# 2017-12-31   nan 29.000 16.000  8.000 3.000   nan
# 2018-06-03   nan 26.000 51.000  5.000 5.000   nan
# 2018-12-31   nan 18.000 24.000  2.000 5.000   nan
# 2019-03-10   nan 15.000    nan    nan   nan   nan
# 2019-04-07   nan 33.000 28.000 18.000   nan   nan
# 2019-04-30   nan 20.000 25.000 36.000   nan   nan
# 2019-09-18   nan    nan 16.000  9.000   nan   nan
# 2019-09-19   nan    nan 17.000 10.000   nan   nan
# 2019-09-20   nan    nan 15.000  7.000   nan   nan
# 2019-09-21   nan    nan 30.000  7.000   nan   nan
# 2019-09-22   nan    nan 14.000  8.000   nan   nan
# 2019-09-23   nan    nan 17.000  6.000   nan   nan
# 2019-09-24   nan    nan 17.000  8.000   nan   nan
# 2019-09-25   nan    nan  8.000  9.000   nan   nan
# 2019-09-26   nan    nan 20.000  6.000   nan   nan
# 2019-09-27   nan    nan 24.000  5.000   nan   nan
# 2019-09-28   nan    nan 21.000  3.000   nan   nan
# 2019-09-29   nan    nan 21.000  4.000   nan   nan
# 2019-09-30   nan    nan 25.000  5.000   nan   nan
# 2019-10-01   nan 12.000 19.000  7.000   nan   nan
# 2019-12-31   nan 21.000 18.000  4.000   nan   nan
# 2020-03-31   nan 20.000 32.000 11.000   nan   nan

# %%
plt.figure(figsize=(25, 15))

cols = list(df.columns)
for i in range(len(cols)):
    plt.subplot(len(cols), 1, i+1)
    plt.title(cols[i].upper())
    plt.plot(df[cols[i]])

# %% [markdown]
# ### Resampling for diffrent intervals & Interpolation of NULLs

# %% [markdown]
# methodstr, default ‘linear’
# Interpolation technique to use. One of:
#
# ‘linear’: Ignore the index and treat the values as equally spaced. This is the only method supported on MultiIndexes.
#
# ‘time’: Works on daily and higher resolution data to interpolate given length of interval.
#
# ‘index’, ‘values’: use the actual numerical values of the index.
#
# ‘pad’: Fill in NaNs using existing values.
#
# ‘nearest’, ‘zero’, ‘slinear’, ‘quadratic’, ‘cubic’, ‘spline’, ‘barycentric’, ‘polynomial’: Passed to scipy.interpolate.interp1d. These methods use the numerical values of the index. Both ‘polynomial’ and ‘spline’ require that you also specify an order (int), e.g. df.interpolate(method='polynomial', order=5).
#
# ‘krogh’, ‘piecewise_polynomial’, ‘spline’, ‘pchip’, ‘akima’, ‘cubicspline’: Wrappers around the SciPy interpolation methods of similar names. See Notes.
#
# ‘from_derivatives’: Refers to scipy.interpolate.BPoly.from_derivatives which replaces ‘piecewise_polynomial’ interpolation method in scipy 0.18.

# %%
data = df.copy()
cols = list(data.columns)
#method = ["nearest", "zero", "slinear", "quadratic", "cubic", "barycentric", "krogh", "piecewise_polynomial", "pchip", "akima", "cubicspline"]
method = ["piecewise_polynomial"]
sample = ["W", "M", "Q", "Y"]
#method = ["piecewise_polynomial", "pchip"]

for i in range(len(cols)):
    for j in range(len(method)):
        for k in range(len(sample)):

            print(cols[i])
            print(method[j])
            print(sample[k])
            
            #before
            
            plt.figure(figsize=(25, 2))
            plt.title(cols[i].upper() + " " + "daily")
            plt.plot(data[cols[i]])
            plt.show()
            
            #after
                        
            data[cols[i]] = data[cols[i]].resample(sample[k]).mean()
            data[cols[i]] = data[cols[i]].interpolate(method=method[j])

            plt.figure(figsize=(25, 2))
            plt.title(sample[k].upper() + " " + cols[i].upper() + " " + method[j].upper())
            plt.plot(data[cols[i]])
            plt.show()
# Out:
# pm25
# piecewise_polynomial
# W
# pm25
# piecewise_polynomial
# M
# pm25
# piecewise_polynomial
# Q
# pm25
# piecewise_polynomial
# Y
# pm10
# piecewise_polynomial
# W
# pm10
# piecewise_polynomial
# M
# pm10
# piecewise_polynomial
# Q
# pm10
# piecewise_polynomial
# Y
# o3
# piecewise_polynomial
# W
# o3
# piecewise_polynomial
# M
# o3
# piecewise_polynomial
# Q
# o3
# piecewise_polynomial
# Y
# no2
# piecewise_polynomial
# W
# no2
# piecewise_polynomial
# M
# no2
# piecewise_polynomial
# Q
# no2
# piecewise_polynomial
# Y
# so2
# piecewise_polynomial
# W
# so2
# piecewise_polynomial
# M
# so2
# piecewise_polynomial
# Q
# so2
# piecewise_polynomial
# Y
# co
# piecewise_polynomial
# W
# co
# piecewise_polynomial
# M
# co
# piecewise_polynomial
# Q
# co
# piecewise_polynomial
# Y

# %%
df.loc['2017-10-13':'2017-10-15']
# Out:
#             pm25   pm10     o3    no2   so2  co
# date
# 2017-10-13   nan    nan 15.000  9.000 2.000 nan
# 2017-10-14   nan    nan 13.000  9.000 1.000 nan
# 2017-10-15   nan 45.000 18.000 18.000 2.000 nan

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x141a9c420d0>,
#  <matplotlib.lines.Line2D at 0x141a9b3e7c0>,
#  <matplotlib.lines.Line2D at 0x141a9b3e460>,
#  <matplotlib.lines.Line2D at 0x141a9b3e2b0>,
#  <matplotlib.lines.Line2D at 0x141a9b3e550>,
#  <matplotlib.lines.Line2D at 0x141a9b3ed30>]
